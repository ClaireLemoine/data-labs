# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

import json
import requests as r
import pandas as pd
from pandas.io.json import json_normalize

response = r.get(url, headers=headers)
response.json()
result=response.json()
flat_data = json_normalize(result)
flat_data
# Out:
#                                             articles  articlesToShow  \
# 0  [{'sku': 'ES422D088-K11', 'name': 'SLIM FIT - ...              84
#
#                                          breadcrumbs carouselTeaser  \
# 0  [{'items': [{'label': 'Homme', 'url_key': 'hom...           None
#
#                                         categoryTree collection  \
# 0  [{'label': 'Promotions', 'id': '9191', 'url_ke...       None
#
#   contentPositions.entry-point-teasers  contentPositions.in-cat-carousel  \
# 0                      [7, 14, 20, 26]                                 9
#
#    contentPositions.in-cat-carousel-fullwidth  \
# 0                                           8
#
#    contentPositions.in-cat-carousel-mobile  ...  upperInCatTeaser  \
# 0                                        6  ...              None
#
#    variants.fullWidthCatalog variants.groupToggleFilters  \
# 0                      False                        True
#
# ...

# %%
flat_data1=json_normalize(flat_data.articles[0])
flat_data1=flat_data1.set_index('sku')

# %%
number_of_loops= result['pagination']['page_count']

# %%
import time

# %%
df=pd.DataFrame()
for i in range (10):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=sale'
    response = r.get(url,headers=headers)
    result=response.json()
    flattened_data=json_normalize(result)
    flattened_data=json_normalize(flattened_data.articles[0])
    flattened_data=flattened_data.set_index('sku')
    df=df.append(flattened_data)
    if i%10==0:
        time.sleep(10)
        
df
# Out:
#               amount             brand_name  \
# sku
# ES422D088-K11    NaN      Esprit Collection
# UN242I00N-Q11    NaN           Under Armour
# GA322P00D-G12    NaN                   GANT
# CO415N03F-A11    NaN               Converse
# L0642D008-A11    NaN          Lacoste Sport
# CO415B09I-A11    NaN               Converse
# NE215O01U-Q11    NaN            New Balance
# AD115B01Y-A11    NaN       adidas Originals
# EL922O02W-A11    NaN                Ellesse
# CO411A0BD-002    NaN               Converse
# EL922S01X-C12    NaN                Ellesse
# CO415B046-Q11    NaN               Converse
# ZA812C001-O12    NaN     Zalando Essentials
# L0642G00D-Q11    NaN          Lacoste Sport
# AD122S088-Q11    NaN       adidas Originals
# SC322G06E-K11    NaN          Scotch & Soda
# EA254H0LD-Q11  110 g                Eastpak
# ZA812M006-O12    NaN     Zalando Essentials
# N1242K03L-Q11    NaN       Nike Performance
# CO411A003-802    NaN               Converse
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

df.brand_name.value_counts().head()
# Out:
# YOURTURN            47
# Jack & Jones        41
# Pier One            38
# Puma                36
# Nike Performance    29
# Name: brand_name, dtype: int64

# %%
df['price.original']=df['price.original'].str.replace(',','.').str.extract('(\d+\.\d*)').astype(float)
df['price.promotional']=df['price.promotional'].str.replace(',','.').str.extract('(\d+\.\d*)').astype(float)

# %%
df['price_diff']=df['price.original']-df['price.promotional']

# %%
total_disc=df[['brand_name','price_diff']].groupby(['brand_name']).sum()
total_disc.sort_values(by='price_diff', ascending=False).index[0]

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

var1=df['price_diff'].sum()/len(df)
print(f'Average discount amount : {var1}')

print(df['price.promotional'].sum()/df['price.original'].sum())
# Out:
# Average discount amount : 15.695095238095238
# 0.7739801541660015
